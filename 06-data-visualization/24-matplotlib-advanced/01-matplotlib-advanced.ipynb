# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## colored Scatterplots

# %%
iris = pd.read_csv('datasets/iris.csv')
iris.head()
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 64    65            5.6           2.9            3.6           1.3
# 143  144            6.8           3.2            5.9           2.3
# 128  129            6.4           2.8            5.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 13    14            4.3           3.0            1.1           0.1
#
#              Species
# 64   Iris-versicolor
# 143   Iris-virginica
# 128   Iris-virginica
# 107   Iris-virginica
# 13       Iris-setosa

# %%
iris['Species'] = iris['Species'].replace({
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
}).infer_objects(copy=False)

# infer_objects(copy=False) for avoiding future errors

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 110  111            6.5           3.2            5.1           2.0        2
# 29    30            4.7           3.2            1.6           0.2        0
# 111  112            6.4           2.7            5.3           1.9        2
# 124  125            6.7           3.3            5.7           2.1        2
# 132  133            6.4           2.8            5.6           2.2        2

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='viridis', alpha=0.8)
plt.xlabel('Sepal Lenght')
plt.ylabel('Petal Lenght')
plt.colorbar()

# %% [markdown]
# ## Plot Size

# %%
plt.figure(figsize=(6,4))

scatter = plt.scatter(
    iris['SepalLengthCm'],
    iris['PetalLengthCm'],
    c=iris['Species'],
    cmap='viridis'
)

plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Sepal vs Petal Length')

plt.colorbar(scatter, label='Species') 
plt.show()

# %% [markdown]
# ## Anotations

# %%
batter = pd.read_csv('datasets/batter.csv')
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batter.shape
# Out:
# (605, 4)

# %%
sample_df = batter.head(100).sample(25, random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'], sample_df['strike_rate'])

# %%
# example

x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)
plt.text(1,5, 'Point 1')
plt.text(2,6, 'Point 2')
plt.text(3,7, 'Point 3')
plt.text(4,8, 'Point 4', fontdict={'size':12, "color":'brown'})
# Out:
# Text(4, 8, 'Point 4')

# %%
plt.figure(figsize=(18,18))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %% [markdown]
# ## horizontal and vertical lines

# %%
plt.figure(figsize=(18,18))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])

plt.axhline(130, color='red') # horizontal
# 130 strike rate

plt.axhline(140, color='green') # horizontal
# 140 strike rate

plt.axvline(30, color='red')  # vertical

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %% [markdown]
# ## subplots

# %%
# A diff way to plot graphs

batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# normal way

plt.figure(figsize=(6,4))

plt.scatter(batter['avg'], batter['strike_rate'])
plt.title('title')
plt.xlabel('Avg')
plt.ylabel('strike rate')
plt.show()

# %%
# another way

fig, ax = plt.subplots(figsize=(10,8))



ax.scatter(batter['avg'], batter['strike_rate'])
ax.set_title('title')
ax.set_xlabel('Avg')
ax.set_ylabel('strike rate')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))

scatter = ax.scatter(
    batter['avg'],
    batter['strike_rate'],
    c=batter['avg'],   # color based on avg
    cmap='coolwarm',
    alpha=0.7
)

ax.set_title('Batsman Performance Analysis')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')

fig.colorbar(scatter, ax=ax, label='Average')

ax.grid(True)

plt.show()

# %%
# mupltipel graphs

plt.subplots(nrows=2, ncols=1)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(nrows=4, ncols=4)
# Out:
# (<Figure size 640x480 with 16 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,10), sharex=True)

ax[0].scatter(batter['avg'], batter['strike_rate'])
ax[1].scatter(batter['avg'], batter['runs'])

ax[0].set_title('Avg VS Strike rate')
ax[0].set_ylabel('Strike rate')



ax[1].set_title('Avg VS Runs')
ax[1].set_xlabel('Avg')
ax[1].set_ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,10))

# First plot
ax[0].scatter(batter['avg'], batter['strike_rate'], alpha=0.7)
ax[0].set_title('Average vs Strike Rate')
ax[0].set_xlabel('Average')
ax[0].set_ylabel('Strike Rate')
ax[0].grid(True)

# Second plot
ax[1].scatter(batter['avg'], batter['runs'], alpha=0.7)
ax[1].set_title('Average vs Runs')
ax[1].set_xlabel('Average')
ax[1].set_ylabel('Runs')
ax[1].grid(True)

plt.tight_layout()   # fixes spacing issue
plt.show()

# %%
# When you have multiple subplots, labels and titles can overlap, spacing becomes messy
# plt.tight_layout() automatically adjusts spacing.

# %%
fig   # it has the figure

# %%
ax  # this has the array
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
ax[0]
# Out:
# <Axes: >

# %%
# histogram

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

# Scatter plots
ax[0,0].scatter(batter['avg'], batter['strike_rate'])
ax[0,0].set_title('Avg vs Strike Rate')
ax[0,0].set_xlabel('Avg')
ax[0,0].set_ylabel('Strike Rate')

ax[0,1].scatter(batter['avg'], batter['runs'])
ax[0,1].set_title('Avg vs Runs')
ax[0,1].set_xlabel('Avg')
ax[0,1].set_ylabel('Runs')

# Histograms
ax[1,0].hist(batter['avg'], bins=20)
ax[1,0].set_title('Average Distribution')
ax[1,0].set_xlabel('Avg')

ax[1,1].hist(batter['runs'], bins=20)
ax[1,1].set_title('Runs Distribution')
ax[1,1].set_xlabel('Runs')

plt.tight_layout()
plt.show()

# %%
# subplot grid created using Matplotlib 

fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(batter['avg'], batter['strike_rate'], color='red')
ax1.set_title('Avg vs Strike Rate')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(batter['runs'], bins=20)
ax2.set_title('Runs Distribution')

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batter['avg'], bins=20)
ax3.set_title('Average Distribution')

plt.tight_layout()
plt.show()

# %%
# This is a subplot grid created using Matplotlib, 
# where multiple visualizations like scatter plots and histograms are displayed in a single figure using add_subplot()
