# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %% [markdown]
# ## Categorical Plots
#
# ### Categorical Scatter Plot
#
# - Stripplot
# - Swarmplot
#
# ### Categorical Distribution Plots
#
# - Boxplot
# - Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
#
# - Barplot
# - Pointplot
# - Countplot
#
# ### Figure level function -> `catplot`

# %%
sns.scatterplot(tips, x='total_bill', y='tip')
# one categorical and numberical col
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Categorical Scatter Plot

# %%
# strip plot

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# strip plot
# axes level function

sns.stripplot(tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(tips, x='day', y='total_bill', jitter=False)

# what is jitter
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot
# figure level function

sns.catplot(tips, x='day', y='total_bill', kind='strip', hue='sex')

# %%
# jitter

sns.catplot(tips, x='day', y='total_bill', kind='strip', hue='sex', jitter=0.3)

# %%
# swarmplot

sns.catplot(tips, x='day', y='total_bill', kind='swarm', hue='sex')

# %%
sns.swarmplot(tips, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Categorical Distribution Plots

# %%
# boxplot

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# <img src='https://miro.medium.com/max/9000/1*2c21SkzJMf3frPXPAR_gZA.png' width=600>

# %%
# box plot

sns.boxplot(tips, x='sex', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(tips, x='day', y='total_bill', hue='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot

sns.catplot(tips, x='sex', y='total_bill', kind='box')

# %%
# hue

sns.boxplot(tips, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# single boxplot --> numerical col

sns.boxplot(tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
## Violinplot(Boxplot + KDEplot)

# %%
sns.violinplot(tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(tips, x='day', y='total_bill', kind='violin', hue='day')

# %%
# hue

sns.catplot(tips, x='day', y='total_bill', kind='violin', hue='sex')

# %%
sns.catplot(tips, x='day', y='total_bill', kind='violin', hue='sex', split=True)

# %% [markdown]
# ### Categorical Estimate Plot (for central tendency)

# %%
# barplot

sns.barplot(tips, x='sex', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
sns.barplot(tips, x='sex', y='total_bill', errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(tips, x='sex', y='total_bill', hue='smoker', estimator='std')   # standard function
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(tips, x='sex', y='total_bill', hue='smoker', estimator='min')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# point plot

sns.pointplot(tips, x='sex', y='total_bill', hue='smoker', estimator='mean')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# point plot
sns.pointplot(tips, x='sex', y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pointplot(tips, x='sex', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# # countplot

# A special case for the bar plot is when you want to show the number of observations 
# in each category rather than computing a statistic for a second variable.
# This is similar to a histogram over a categorical, rather than quantitative, variable

# %%
sns.countplot(tips, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(tips, x='sex', hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# facerting using catplot

sns.catplot(tips, x='sex', y='total_bill', col='smoker', kind='box')

# %%
sns.catplot(tips, x='sex', y='total_bill', col='smoker', row='time', kind='box')

# %% [markdown]
# ## Regression Plots
#
# - regplot
# - lmplot
#
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# axes level
# hue parameter is not available
sns.regplot(tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(tips, x='total_bill', y='tip', hue='sex')

# %%
# residplot

sns.residplot(tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## A second way to plot Facet plots -> FacetGrid

# %%
# figure level -> relplot -> displot -> catplot -> lmplot

sns.catplot(tips, x='sex', y='total_bill', kind='violin', col='day', row='time')

# %%
g = sns.FacetGrid(tips, col='day', row='time')
g.map(sns.violinplot, 'sex', 'total_bill', order=['Male', 'Female'])

# %%
g = sns.FacetGrid(tips, col='day', row='time', hue='smoker')
g.map(sns.violinplot, 'sex', 'total_bill', order=['Male', 'Female'])
g.add_legend()

# %%
# Seaborn now recommends using map_dataframe

g = sns.FacetGrid(tips, col='day', row='time')
g.map_dataframe(sns.violinplot, x='sex', y='total_bill', order=['Male', 'Female'])

# %% [markdown]
# ## Plotting Pairwise Relationship (PairGrid Vs Pairplot)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# pair plot

sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
# Pair Grid

g = sns.PairGrid(iris, hue='species')
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(iris, hue='species')
g.map(sns.histplot)

# %%
# map_diag --> map_offdiag
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.kdeplot)

# %%
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.boxplot)
g.map_offdiag(sns.kdeplot)

# %%
# map_diag --> map_upper --> map_lower
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
# vars

g = sns.PairGrid(data=iris,hue='species', vars=['sepal_width', 'petal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# ## JointGrid Vs Jointplot

# %%
# join plot

sns.jointplot(tips, x='total_bill', y='tip')

# %%
sns.jointplot(tips, x='total_bill', y='tip', kind='hist', hue='sex')

# %%
sns.jointplot(tips, x='total_bill', y='tip', kind='kde', hue='sex')

# %%
# joint grid

g = sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.scatterplot,sns.histplot)

# %%
g = sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.kdeplot,sns.violinplot)

# %% [markdown]
# ### Utility Functions

# %%
# get dataset names
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load dataset
sns.load_dataset('taxis')
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...
